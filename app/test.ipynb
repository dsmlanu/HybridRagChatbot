# %%
import requests
import os

key = os.getenv("GROQ_API_KEY")
key="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"
print(key)


url = "https://api.groq.com/openai/v1/chat/completions"
payload = {
    "model": "llama-3.3-70b-versatile",
    "messages": [{"role": "user", "content": "Hi there!"}]
}

res = requests.post(url, json=payload, headers={
    "Authorization": f"Bearer {key}",
    "Content-Type": "application/json"
})

print(res.status_code, res.text)
# Out:
# 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
# 200 {"id":"chatcmpl-e6bebede-168a-413d-ad77-91136cde01f8","object":"chat.completion","created":1767385235,"model":"llama-3.3-70b-versatile","choices":[{"index":0,"message":{"role":"assistant","content":"It's nice to meet you. Is there something I can help you with, or would you like to chat?"},"logprobs":null,"finish_reason":"stop"}],"usage":{"queue_time":0.162411916,"prompt_tokens":38,"prompt_time":0.000928514,"completion_tokens":24,"completion_time":0.047047097,"total_tokens":62,"total_time":0.047975611},"usage_breakdown":null,"system_fingerprint":"fp_45180df409","x_groq":{"id":"req_01ke05wzsrfk1vpjtzmppqnyv6","seed":1842630027},"service_tier":"on_demand"}
